# %%
from baselines.common import plot_util as pu

# %% [markdown]
# If you want to average results for multiple seeds, LOG_DIRS must contain subfolders in the following format: ```<name_exp0>-0```, ```<name_exp0>-1```, ```<name_exp1>-0```, ```<name_exp1>-1```. Where names correspond to experiments you want to compare separated with random seeds by dash.

# %%
LOG_DIRS = './logs/PongNoFrameskip-v4/distill_test'
LOG_DIRS2 = './logs2/DemonAttackNoFrameskip-v4/distill_test'
a = [0,0]
#a[0] = LOG_DIRS
#a[1] = LOG_DIRS2
# Uncomment below to see the effect of the timit limits flag
# LOG_DIRS = 'time_limit_logs/reacher'

# %%
results = pu.load_results(a)
results2 = pu.load_results(LOG_DIRS2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-52ba818e3586> in <module>
# ----> 1 results = pu.load_results(a)
#       2 results2 = pu.load_results(LOG_DIRS2)
#
# c:\users\joo\documents\pycharmprojects\test2\baselines\baselines\common\plot_util.py in load_results(root_dir_or_dirs, enable_progress, enable_monitor, verbose)
#     173         rootdirs = [osp.expanduser(root_dir_or_dirs)]
#     174     else:
# --> 175         rootdirs = [osp.expanduser(d) for d in root_dir_or_dirs]
#     176     allresults = []
#     177     for rootdir in rootdirs:
#
# c:\users\joo\documents\pycharmprojects\test2\baselines\baselines\common\plot_util.py in <listcomp>(.0)
#     173         rootdirs = [osp.expanduser(root_dir_or_dirs)]
#     174     else:
# --> 175         rootdirs = [osp.expanduser(d) for d in root_dir_or_dirs]
#     176     allresults = []
# ...

# %%
fig = pu.plot_results(results, average_group=False, split_fn=lambda _: '', shaded_std=False,xlabel='Time', ylabel='Reward', title="PongNoFrameskip", figsize = (5,5), save = False)
fig = pu.plot_results(results, average_group=False, split_fn=lambda _: '', shaded_std=False,xlabel='Time', ylabel='Reward', title="DemonAttackNoFrameskip", figsize = (5,5), save = False)
#fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False,xlabel='Time', ylabel='Reward', title="PongNoFrameskip-v4", figsize = (5,5), save = False)
#fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False,xlabel='Time', ylabel='Reward', title="DemonAttackNoFrameskip-v4", figsize = (5,5), save = False)

# %%
fig = pu.plot_results(results2, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# No handles with labels found to put in legend.
